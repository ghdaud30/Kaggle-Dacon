# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
data = np.arange(5,0,-1)
plt.plot(data)

# %%
fig , ax = plt.subplots(3,3)

# %%
x = np.linspace(0,2,100)
fig , ax = plt.subplots()

ax.plot(x,x,label='linear')
ax.plot(x,x**2,label="quadratic")
ax.plot(x,x**3,label="cubic")
ax.set_xlabel("x label")
ax.set_ylabel("y label")
ax.set_title('title')
ax.legend()
plt.show()

# %%
x = np.linspace(0,2,100)

plt.plot(x,x,label='linear')
plt.plot(x,x**2,label="quadratic")
plt.plot(x,x**3,label="cubic")
plt.xlabel("x label")
plt.ylabel("y label")
plt.title('title')
plt.legend()
plt.show()

# %%
labels = ['Test1','Test2','Test3','Test4','Test5','Test6']
group_one_price = [30,40,50,60,70,80]
group_two_price = [10,20,30,40,50,60]
group_one_tax = [1,2,1,2,1,2]
group_one_two = [3,4,3,4,3,4]
fig,ax = plt.subplots()
ax.bar(labels, group_one_price)
ax.bar(labels, group_two_price)
# Out:
# <BarContainer object of 6 artists>

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day', y='total_bill', data=df)

# %%
penguins =  sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_theme("talk")
sns.relplot(x='flipper_length_mm', y= 'bill_length_mm', data=penguins, col = 'island', hue ='sex', style ='species')

# %%
# !gdown 1KcZscEhVAZaU-uiWbLd5Vb_qLuvLoVhT
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KcZscEhVAZaU-uiWbLd5Vb_qLuvLoVhT
# To: /content/lab-data.zip
# 100% 302M/302M [00:01<00:00, 237MB/s]

# %%
# !unzip lab-data.zip
# Out:
# Archive:  lab-data.zip
#   inflating: lab1-baby-20231019.csv
#   inflating: lab2-airline-20231026.csv
#   inflating: lab2-airline-by-region-20231026.csv
#   inflating: sakila.db
#    creating: 상가정보_20230630/
#   inflating: 상가정보_20230630/강원_202306.csv
#   inflating: 상가정보_20230630/경기_202306.csv
#   inflating: 상가정보_20230630/경남_202306.csv
#   inflating: 상가정보_20230630/경북_202306.csv
#   inflating: 상가정보_20230630/광주_202306.csv
#   inflating: 상가정보_20230630/대구_202306.csv
#   inflating: 상가정보_20230630/대전_202306.csv
#   inflating: 상가정보_20230630/부산_202306.csv
#   inflating: 상가정보_20230630/서울_202306.csv
#   inflating: 상가정보_20230630/세종_202306.csv
#   inflating: 상가정보_20230630/울산_202306.csv
#   inflating: 상가정보_20230630/인천_202306.csv
#   inflating: 상가정보_20230630/전남_202306.csv
#   inflating: 상가정보_20230630/전북_202306.csv
#   inflating: 상가정보_20230630/제주_202306.csv
#   inflating: 상가정보_20230630/충남_202306.csv
#   inflating: 상가정보_20230630/충북_202306.csv

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 38.0 MB/s eta 0:00:00
# ...

# %%
df = pd.read_csv("/content/lab1-baby-20231019.csv",encoding='cp949')
df.head(5)
# Out:
#     시군구별 1997.01 1997.01.1 1997.01.2 1997.02 1997.02.1 1997.02.2 1997.03  \
# 0   시군구별   계 (명)    남자 (명)    여자 (명)   계 (명)    남자 (명)    여자 (명)   계 (명)
# 1     전국   63268     33266     30002   58144     30086     28058   62160
# 2  서울특별시   13205      6886      6319   12239      6224      6015   13358
# 3  부산광역시    4201      2260      1941    3910      2104      1806    4304
# 4  대구광역시    3345      1764      1581    2994      1608      1386    3337
#
#   1997.03.1 1997.03.2  ... 2022.09.2 2022.10 2022.10.1 2022.10.2 2022.11  \
# 0    남자 (명)    여자 (명)  ...    여자 (명)   계 (명)    남자 (명)    여자 (명)   계 (명)
# 1     32333     29827  ...     10715   20646     10530     10116   18981
# 2      6947      6411  ...      1831    3612      1794      1818    3230
# 3      2234      2070  ...       575    1166       602       564     977
# 4      1815      1522  ...       416     848       428       420     802
#
#   2022.11.1 2022.11.2 2022.12 2022.12.1 2022.12.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Columns: 937 entries, 시군구별 to 2022.12.2
# dtypes: object(937)
# memory usage: 139.2+ KB

# %%
df_melt = df.melt(id_vars = '시군구별')
df_melt.head(30)
# Out:
#        시군구별   variable   value
# 0      시군구별    1997.01   계 (명)
# 1        전국    1997.01   63268
# 2     서울특별시    1997.01   13205
# 3     부산광역시    1997.01    4201
# 4     대구광역시    1997.01    3345
# 5     인천광역시    1997.01    3646
# 6     광주광역시    1997.01    2166
# 7     대전광역시    1997.01    2003
# 8     울산광역시    1997.01    1754
# 9   세종특별자치시    1997.01       -
# 10      경기도    1997.01   13440
# 11      강원도    1997.01    1794
# 12     충청북도    1997.01    2075
# 13     충청남도    1997.01    2259
# 14     전라북도    1997.01    2579
# 15     전라남도    1997.01    2685
# 16     경상북도    1997.01    3362
# 17     경상남도    1997.01    4020
# 18  제주특별자치도    1997.01     734
# 19     시군구별  1997.01.1  남자 (명)
# 20       전국  1997.01.1   33266
# 21    서울특별시  1997.01.1    6886
# 22    부산광역시  1997.01.1    2260
# 23    대구광역시  1997.01.1    1764
# 24    인천광역시  1997.01.1    1878
# 25    광주광역시  1997.01.1    1106
# 26    대전광역시  1997.01.1    1055
# 27    울산광역시  1997.01.1     935
# 28  세종특별자치시  1997.01.1       -
# ...

# %%
df_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17784 entries, 0 to 17783
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구별      17784 non-null  object
#  1   variable  17784 non-null  object
#  2   value     17784 non-null  object
# dtypes: object(3)
# memory usage: 416.9+ KB

# %%
df_melt['시군구별'].unique()
# Out:
# array(['시군구별', '전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',
#        '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
#        '경상북도', '경상남도', '제주특별자치도'], dtype=object)

# %%
df_melt = df_melt[df_melt['시군구별'] != '시군구별']
df_melt[df_melt['시군구별'] != '시군구별']
# Out:
#           시군구별   variable  value
# 1           전국    1997.01  63268
# 2        서울특별시    1997.01  13205
# 3        부산광역시    1997.01   4201
# 4        대구광역시    1997.01   3345
# 5        인천광역시    1997.01   3646
# ...        ...        ...    ...
# 17779     전라북도  2022.12.2    229
# 17780     전라남도  2022.12.2    250
# 17781     경상북도  2022.12.2    366
# 17782     경상남도  2022.12.2    503
# 17783  제주특별자치도  2022.12.2    121
#
# [16848 rows x 3 columns]

# %%
df_melt['시군구별'].unique()
# Out:
# array(['전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',
#        '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
#        '경상북도', '경상남도', '제주특별자치도'], dtype=object)

# %%
df_melt['variable']
# Out:
# 1          1997.01
# 2          1997.01
# 3          1997.01
# 4          1997.01
# 5          1997.01
#            ...
# 17779    2022.12.2
# 17780    2022.12.2
# 17781    2022.12.2
# 17782    2022.12.2
# 17783    2022.12.2
# Name: variable, Length: 16848, dtype: object

# %%
df_melt["variable"].str.split('.')
# Out:
# 1           [1997, 01]
# 2           [1997, 01]
# 3           [1997, 01]
# 4           [1997, 01]
# 5           [1997, 01]
#              ...
# 17779    [2022, 12, 2]
# 17780    [2022, 12, 2]
# 17781    [2022, 12, 2]
# 17782    [2022, 12, 2]
# 17783    [2022, 12, 2]
# Name: variable, Length: 16848, dtype: object

# %%
df_melt["variable"].str.split('.' , expand = True)
# Out:
#           0   1     2
# 1      1997  01  None
# 2      1997  01  None
# 3      1997  01  None
# 4      1997  01  None
# 5      1997  01  None
# ...     ...  ..   ...
# 17779  2022  12     2
# 17780  2022  12     2
# 17781  2022  12     2
# 17782  2022  12     2
# 17783  2022  12     2
#
# [16848 rows x 3 columns]

# %%
df_melt['연도'] =  df_melt["variable"].str.split('.' , expand = True)[0]
df_melt['월'] =  df_melt["variable"].str.split('.' , expand = True)[1]
df_melt['성별'] =  df_melt["variable"].str.split('.' , expand = True)[2]
df_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16848 entries, 1 to 17783
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구별      16848 non-null  object
#  1   variable  16848 non-null  object
#  2   value     16848 non-null  object
#  3   연도        16848 non-null  object
#  4   월         16848 non-null  object
#  5   일         11232 non-null  object
#  6   성별        11232 non-null  object
# dtypes: object(7)
# memory usage: 1.0+ MB

# %%
df_melt
# Out:
#           시군구별   variable  value    연도   월    성별
# 1           전국    1997.01  63268  1997  01  None
# 2        서울특별시    1997.01  13205  1997  01  None
# 3        부산광역시    1997.01   4201  1997  01  None
# 4        대구광역시    1997.01   3345  1997  01  None
# 5        인천광역시    1997.01   3646  1997  01  None
# ...        ...        ...    ...   ...  ..   ...
# 17779     전라북도  2022.12.2    229  2022  12     2
# 17780     전라남도  2022.12.2    250  2022  12     2
# 17781     경상북도  2022.12.2    366  2022  12     2
# 17782     경상남도  2022.12.2    503  2022  12     2
# 17783  제주특별자치도  2022.12.2    121  2022  12     2
#
# [16848 rows x 6 columns]

# %%
df_melt['성별'] = df_melt['성별'].fillna('전체')
df_melt['성별']
# Out:
# 1        전체
# 2        전체
# 3        전체
# 4        전체
# 5        전체
#          ..
# 17779     2
# 17780     2
# 17781     2
# 17782     2
# 17783     2
# Name: 성별, Length: 16848, dtype: object

# %%
df_melt['성별'] = df_melt['성별'].replace('1','남자').replace(2,'여자')
df_melt['성별']
# Out:
# 1        전체
# 2        전체
# 3        전체
# 4        전체
# 5        전체
#          ..
# 17779     2
# 17780     2
# 17781     2
# 17782     2
# 17783     2
# Name: 성별, Length: 16848, dtype: object

# %%
df_melt = df_melt.rename(columns ={"variable" : "기간" , "value":"출생아수"})
df_melt['출생아수']
# Out:
# 1        63268
# 2        13205
# 3         4201
# 4         3345
# 5         3646
#          ...
# 17779      229
# 17780      250
# 17781      366
# 17782      503
# 17783      121
# Name: 출생아수, Length: 16848, dtype: object

# %%
df_melt.head()
# Out:
#     시군구별       기간   출생아수    연도   월  성별
# 1     전국  1997.01  63268  1997  01  전체
# 2  서울특별시  1997.01  13205  1997  01  전체
# 3  부산광역시  1997.01   4201  1997  01  전체
# 4  대구광역시  1997.01   3345  1997  01  전체
# 5  인천광역시  1997.01   3646  1997  01  전체

# %%
df_melt['연도']
# Out:
# 1        1997
# 2        1997
# 3        1997
# 4        1997
# 5        1997
#          ...
# 17779    2022
# 17780    2022
# 17781    2022
# 17782    2022
# 17783    2022
# Name: 연도, Length: 16848, dtype: object

# %%
df_melt = df_melt.drop('일',axis= 1)

# %%
df_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16848 entries, 1 to 17783
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구별    16848 non-null  object
#  1   기간      16848 non-null  object
#  2   출생아수    16848 non-null  object
#  3   연도      16848 non-null  object
#  4   월       16848 non-null  object
#  5   성별      16848 non-null  object
# dtypes: object(6)
# memory usage: 921.4+ KB

# %%
df_melt.isnull().sum()
# Out:
# 시군구별    0
# 기간      0
# 출생아수    0
# 연도      0
# 월       0
# 성별      0
# dtype: int64

# %%
df_melt['출생아수'].value_counts()
# Out:
# -        540
# 549       29
# 656       26
# 609       23
# 588       23
#         ...
# 3696       1
# 38031      1
# 7965       1
# 2243       1
# 8212       1
# Name: 출생아수, Length: 4985, dtype: int64

# %%
df_melt[df_melt['출생아수'] == '-']
# Out:
#           시군구별         기간 출생아수    연도   월  성별
# 9      세종특별자치시    1997.01    -  1997  01  전체
# 28     세종특별자치시  1997.01.1    -  1997  01  남자
# 47     세종특별자치시  1997.01.2    -  1997  01   2
# 66     세종특별자치시    1997.02    -  1997  02  전체
# 85     세종특별자치시  1997.02.1    -  1997  02  남자
# ...        ...        ...  ...   ...  ..  ..
# 10174  세종특별자치시  2011.11.1    -  2011  11  남자
# 10193  세종특별자치시  2011.11.2    -  2011  11   2
# 10212  세종특별자치시    2011.12    -  2011  12  전체
# 10231  세종특별자치시  2011.12.1    -  2011  12  남자
# 10250  세종특별자치시  2011.12.2    -  2011  12   2
#
# [540 rows x 6 columns]

# %%
df_melt['출생아수'] = df_melt['출생아수'].replace('-',np.nan).astype(float)

# %%
df_melt['출생아수']
# Out:
# 1        63268.0
# 2        13205.0
# 3         4201.0
# 4         3345.0
# 5         3646.0
#           ...
# 17779      229.0
# 17780      250.0
# 17781      366.0
# 17782      503.0
# 17783      121.0
# Name: 출생아수, Length: 16848, dtype: float64

# %%
df_melt['출생아수'].isnull().sum()
# Out:
# 540

# %%
df_melt['시군구별']
# Out:
# 1             전국
# 2          서울특별시
# 3          부산광역시
# 4          대구광역시
# 5          인천광역시
#           ...
# 17779       전라북도
# 17780       전라남도
# 17781       경상북도
# 17782       경상남도
# 17783    제주특별자치도
# Name: 시군구별, Length: 16848, dtype: object

# %%
plt.figure(figsize=[30,4])
sns.lineplot(x ='연도',
             y='출생아수',
             data =df_melt,
             hue = '월',
             ci = None)
# Out:
# <ipython-input-56-c32b8492b5a4>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x ='연도',
# <Axes: xlabel='연도', ylabel='출생아수'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
plt.figure(figsize=[30,4])
sns.pointplot(x ='연도',
             y='출생아수',
             data =df_melt,
             hue = '월',
             ci = None)
sns.barplot(x ='연도',
             y='출생아수',
             data =df_melt,
             hue = '월',
             ci = None)
# Out:
# <ipython-input-59-b31379be29b7>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x ='연도',
# <ipython-input-59-b31379be29b7>:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x ='연도',
# <Axes: xlabel='연도', ylabel='출생아수'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
df_melt[(df_melt['시군구별'] != '전국') & (df_melt['연도'] != '1997')]
# Out:
#           시군구별         기간     출생아수    연도   월  성별
# 686      서울특별시    1998.01  12759.0  1998  01  전체
# 687      부산광역시    1998.01   3960.0  1998  01  전체
# 688      대구광역시    1998.01   2970.0  1998  01  전체
# 689      인천광역시    1998.01   3370.0  1998  01  전체
# 690      광주광역시    1998.01   2009.0  1998  01  전체
# ...        ...        ...      ...   ...  ..  ..
# 17779     전라북도  2022.12.2    229.0  2022  12   2
# 17780     전라남도  2022.12.2    250.0  2022  12   2
# 17781     경상북도  2022.12.2    366.0  2022  12   2
# 17782     경상남도  2022.12.2    503.0  2022  12   2
# 17783  제주특별자치도  2022.12.2    121.0  2022  12   2
#
# [15300 rows x 6 columns]

# %%
plt.figure(figsize=[30,8])
sns.pointplot(x ='연도',
             y='출생아수',
             data =df_melt,
             hue = '시군구별',
             errorbar = None
             )
plt.legend(loc='best')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
plt.figure(figsize=[30,8])
sns.relplot(x ='연도',
             y='출생아수',
             data =df_melt,
             hue = '시군구별',
             col = '시군구별',
             kind = 'line'
             )
plt.legend(loc='best')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 44400 (\N{HANGUL SYLLABLE GUN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
df = pd.read_csv("/content/상가정보_20230630/부산_202306.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-f6b548186043> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/상가정보_20230630/부산_202306.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df = pd.read_csv('/content/부산_202306.csv')
# Out:
# <ipython-input-66-fd5eb898ed0e>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/부산_202306.csv')

# %%
df
# Out:
#                       상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0072343         선해횟집  NaN        I2       음식      I201
# 1       MA010120220805430802          미즈노  NaN        G2       소매      G209
# 2       MA010120220805430814          리스트  NaN        G2       소매      G209
# 3       MA010120220805430900  눈썹그리기교실동안눈썹  NaN        S2    수리·개인      S207
# 4       MA010120220805430935    카페051남포역점  NaN        I2       음식      I212
# ...                      ...          ...  ...       ...      ...       ...
# 153526  MA0101202307A0067231         해동반찬  NaN        G2       소매      G205
# 153527  MA0101202307A0053908         써니데이  NaN        I2       음식      I212
# 153528  MA0101202307A0007674     타코이찌타코야끼  하단점        I2       음식      I204
# 153529  MA0101202307A0060093     히어로드림에프씨  NaN        P1       교육      P106
# 153530  MA0101202307A0056030           소망  NaN        G2       소매      G215
#
# ...

# %%
df_melt = df.melt(id_vars ='표준산업분류코드')
df_melt
# Out:
#         표준산업분류코드 variable                 value
# 0         I56111   상가업소번호  MA0101202210A0072343
# 1         G47419   상가업소번호  MA010120220805430802
# 2         G47412   상가업소번호  MA010120220805430814
# 3         S96113   상가업소번호  MA010120220805430900
# 4         I56221   상가업소번호  MA010120220805430935
# ...          ...      ...                   ...
# 5834173   G47218       위도             35.159462
# 5834174   I56221       위도             35.319494
# 5834175   I56194       위도              35.11049
# 5834176   P85612       위도             35.138025
# 5834177   G47813       위도             35.111664
#
# [5834178 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153531 entries, 0 to 153530
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     153531 non-null  object
#  1   상호명        153530 non-null  object
#  2   지점명        1893 non-null    object
#  3   상권업종대분류코드  153531 non-null  object
#  4   상권업종대분류명   153531 non-null  object
#  5   상권업종중분류코드  153531 non-null  object
#  6   상권업종중분류명   153531 non-null  object
#  7   상권업종소분류코드  153531 non-null  object
#  8   상권업종소분류명   153531 non-null  object
#  9   표준산업분류코드   153509 non-null  object
#  10  표준산업분류명    153509 non-null  object
#  11  시도코드       153531 non-null  int64
#  12  시도명        153531 non-null  object
#  13  시군구코드      153531 non-null  int64
#  14  시군구명       153531 non-null  object
#  15  행정동코드      153531 non-null  int64
#  16  행정동명       153531 non-null  object
#  17  법정동코드      153531 non-null  int64
#  18  법정동명       153531 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# 상가업소번호            0
# 상호명               1
# 지점명          151638
# 상권업종대분류코드         0
# 상권업종대분류명          0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종소분류명          0
# 표준산업분류코드         22
# 표준산업분류명          22
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명              0
# 행정동코드             0
# 행정동명              0
# 법정동코드             0
# 법정동명              0
# 지번코드              0
# 대지구분코드            0
# 대지구분명             0
# 지번본번지             1
# 지번부번지         17336
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 건물본번지             0
# 건물부번지        129142
# 건물관리번호            3
# 건물명          101546
# 도로명주소             0
# 구우편번호             0
# 신우편번호             0
# 동정보          153531
# 층정보           73165
# 호정보          153531
# 경도                0
# 위도                0
# dtype: int64

# %%
n = df.isnull().sum()
n
# Out:
# 상가업소번호            0
# 상호명               1
# 지점명          151638
# 상권업종대분류코드         0
# 상권업종대분류명          0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종소분류명          0
# 표준산업분류코드         22
# 표준산업분류명          22
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명              0
# 행정동코드             0
# 행정동명              0
# 법정동코드             0
# 법정동명              0
# 지번코드              0
# 대지구분코드            0
# 대지구분명             0
# 지번본번지             1
# 지번부번지         17336
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 건물본번지             0
# 건물부번지        129142
# 건물관리번호            3
# 건물명          101546
# 도로명주소             0
# 구우편번호             0
# 신우편번호             0
# 동정보          153531
# 층정보           73165
# 호정보          153531
# 경도                0
# 위도                0
# dtype: int64

# %%
n.sort_values()
# Out:
# 상가업소번호            0
# 신우편번호             0
# 구우편번호             0
# 도로명주소             0
# 건물본번지             0
# 도로명               0
# 도로명코드             0
# 지번주소              0
# 대지구분명             0
# 대지구분코드            0
# 경도                0
# 법정동명              0
# 법정동코드             0
# 행정동명              0
# 행정동코드             0
# 지번코드              0
# 시군구코드             0
# 상권업종대분류코드         0
# 시군구명              0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종대분류명          0
# 상권업종소분류명          0
# 시도코드              0
# 시도명               0
# 위도                0
# 상호명               1
# 지번본번지             1
# 건물관리번호            3
# 표준산업분류코드         22
# 표준산업분류명          22
# 지번부번지         17336
# 층정보           73165
# 건물명          101546
# 건물부번지        129142
# 지점명          151638
# 동정보          153531
# 호정보          153531
# dtype: int64

# %%
not_use = n.sort_values(ascending=False).head(9)
not_use_col = not_use.index
not_use_col
# Out:
# Index(['호정보', '동정보', '지점명', '건물부번지', '건물명', '층정보', '지번부번지', '표준산업분류코드',
#        '표준산업분류명'],
#       dtype='object')

# %%
df = df.drop(not_use_col,axis=1)
df
# Out:
#                       상가업소번호          상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0072343         선해횟집        I2       음식      I201
# 1       MA010120220805430802          미즈노        G2       소매      G209
# 2       MA010120220805430814          리스트        G2       소매      G209
# 3       MA010120220805430900  눈썹그리기교실동안눈썹        S2    수리·개인      S207
# 4       MA010120220805430935    카페051남포역점        I2       음식      I212
# ...                      ...          ...       ...      ...       ...
# 153526  MA0101202307A0067231         해동반찬        G2       소매      G205
# 153527  MA0101202307A0053908         써니데이        I2       음식      I212
# 153528  MA0101202307A0007674     타코이찌타코야끼        I2       음식      I204
# 153529  MA0101202307A0060093     히어로드림에프씨        P1       교육      P106
# 153530  MA0101202307A0056030           소망        G2       소매      G215
#
#            상권업종중분류명 상권업종소분류코드    상권업종소분류명  시도코드    시도명  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153531 entries, 0 to 153530
# Data columns (total 30 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     153531 non-null  object
#  1   상호명        153530 non-null  object
#  2   상권업종대분류코드  153531 non-null  object
#  3   상권업종대분류명   153531 non-null  object
#  4   상권업종중분류코드  153531 non-null  object
#  5   상권업종중분류명   153531 non-null  object
#  6   상권업종소분류코드  153531 non-null  object
#  7   상권업종소분류명   153531 non-null  object
#  8   시도코드       153531 non-null  int64
#  9   시도명        153531 non-null  object
#  10  시군구코드      153531 non-null  int64
#  11  시군구명       153531 non-null  object
#  12  행정동코드      153531 non-null  int64
#  13  행정동명       153531 non-null  object
#  14  법정동코드      153531 non-null  int64
#  15  법정동명       153531 non-null  object
#  16  지번코드       153531 non-null  int64
#  17  대지구분코드     153531 non-null  int64
#  18  대지구분명      153531 non-null  object
# ...

# %%
cols = df.columns
cols_code = cols[cols.str.contains('코드|번호]')]
cols_code
# Out:
# Index(['상권업종대분류코드', '상권업종중분류코드', '상권업종소분류코드', '시도코드', '시군구코드', '행정동코드',
#        '법정동코드', '지번코드', '대지구분코드', '도로명코드'],
#       dtype='object')

# %%
df = df.drop(cols_code , axis = 1)

# %%
df
# Out:
#                       상가업소번호          상호명 상권업종대분류명     상권업종중분류명    상권업종소분류명  \
# 0       MA0101202210A0072343         선해횟집       음식           한식          횟집
# 1       MA010120220805430802          미즈노       소매  섬유·의복·신발 소매   기타 의류 소매업
# 2       MA010120220805430814          리스트       소매  섬유·의복·신발 소매   여성 의류 소매업
# 3       MA010120220805430900  눈썹그리기교실동안눈썹    수리·개인        이용·미용      피부 관리실
# 4       MA010120220805430935    카페051남포역점       음식        비알코올           카페
# ...                      ...          ...      ...          ...         ...
# 153526  MA0101202307A0067231         해동반찬       소매       식료품 소매  반찬/식료품 소매업
# 153527  MA0101202307A0053908         써니데이       음식        비알코올           카페
# 153528  MA0101202307A0007674     타코이찌타코야끼       음식          서양식  기타 서양식 음식점
# 153529  MA0101202307A0060093     히어로드림에프씨       교육        기타 교육  요가/필라테스 학원
# 153530  MA0101202307A0056030           소망       소매    의약·화장품 소매     화장품 소매업
#
# ...

# %%
df.to_csv('중간저장.csv',index=None)

# %%
pd.read_csv("중간저장.csv")
# Out:
#                       상가업소번호          상호명 상권업종대분류명     상권업종중분류명    상권업종소분류명  \
# 0       MA0101202210A0072343         선해횟집       음식           한식          횟집
# 1       MA010120220805430802          미즈노       소매  섬유·의복·신발 소매   기타 의류 소매업
# 2       MA010120220805430814          리스트       소매  섬유·의복·신발 소매   여성 의류 소매업
# 3       MA010120220805430900  눈썹그리기교실동안눈썹    수리·개인        이용·미용      피부 관리실
# 4       MA010120220805430935    카페051남포역점       음식        비알코올           카페
# ...                      ...          ...      ...          ...         ...
# 153526  MA0101202307A0067231         해동반찬       소매       식료품 소매  반찬/식료품 소매업
# 153527  MA0101202307A0053908         써니데이       음식        비알코올           카페
# 153528  MA0101202307A0007674     타코이찌타코야끼       음식          서양식  기타 서양식 음식점
# 153529  MA0101202307A0060093     히어로드림에프씨       교육        기타 교육  요가/필라테스 학원
# 153530  MA0101202307A0056030           소망       소매    의약·화장품 소매     화장품 소매업
#
# ...
