# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\ghdau\AppData\Roaming\Python\Python38\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#   Using cached koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import koreanize_matplotlib

# %% [markdown]
# csv > DF > 전처리 > 필터링 > 서브셋 > EDA

# %% [markdown]
# Q1. 이디야와 스타벅스는 근거리에 위치하는가?? 에 대한 사실 증명을 위한 EDA

# %%
df = pd.read_csv('./data/부산_202203.csv')
df.info()
# Out:
# C:\Users\ghdau\AppData\Local\Temp\ipykernel_11804\3878295762.py:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/부산_202203.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147799 entries, 0 to 147798
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     147799 non-null  int64
#  1   상호명        147798 non-null  object
#  2   지점명        22032 non-null   object
#  3   상권업종대분류코드  147799 non-null  object
#  4   상권업종대분류명   147799 non-null  object
#  5   상권업종중분류코드  147799 non-null  object
#  6   상권업종중분류명   147799 non-null  object
#  7   상권업종소분류코드  147799 non-null  object
#  8   상권업종소분류명   147799 non-null  object
#  9   표준산업분류코드   138317 non-null  object
#  10  표준산업분류명    138317 non-null  object
#  11  시도코드       147799 non-null  int64
#  12  시도명        147799 non-null  object
#  13  시군구코드      147799 non-null  int64
# ...

# %%
df.head(2)
# Out:
#      상가업소번호    상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명 상권업종소분류코드  \
# 0  23206623    미광장  NaN         O       숙박       O02  모텔/여관/여인숙    O02A01
# 1  20418637  BHC치킨  동래점         Q       음식       Q05     닭/오리요리    Q05A08
#
#     상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0  모텔/여관/여인숙   I55112  ...  2611012600100250001004473  NaN
# 1  후라이드/양념치킨   I56193  ...  2626010500101850000016529  NaN
#
#                    도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0    부산광역시 중구 보수대로44번길 5  600074  48974.0  NaN  NaN  NaN  129.023668
# 1  부산광역시 동래구 동래로147번길 18  607020  47802.0  NaN  NaN  NaN  129.087156
#
#           위도
# 0  35.100979
# 1  35.205267
#
# [2 rows x 39 columns]

# %%
df.isna().sum()
# Out:
# 상가업소번호            0
# 상호명               1
# 지점명          125767
# 상권업종대분류코드         0
# 상권업종대분류명          0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종소분류명          0
# 표준산업분류코드       9482
# 표준산업분류명        9482
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명              0
# 행정동코드             0
# 행정동명              6
# 법정동코드             0
# 법정동명              0
# 지번코드              0
# 대지구분코드            0
# 대지구분명             0
# 지번본번지             0
# 지번부번지         22868
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 건물본번지             0
# 건물부번지        126249
# 건물관리번호            0
# 건물명           86112
# 도로명주소             0
# 구우편번호             0
# 신우편번호            13
# 동정보          128185
# 층정보           84781
# 호정보          147799
# 경도                0
# 위도                0
# dtype: int64

# %%
df.isna().sum().plot.barh(figsize=[8,9])
# Out:
# <Axes: >

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# 호정보          147799
# 동정보          128185
# 건물부번지        126249
# 지점명          125767
# 건물명           86112
# 층정보           84781
# 지번부번지         22868
# 표준산업분류코드       9482
# 표준산업분류명        9482
# 신우편번호            13
# 행정동명              6
# 상호명               1
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 상가업소번호            0
# 건물본번지             0
# 건물관리번호            0
# 지번본번지             0
# 구우편번호             0
# 경도                0
# 도로명주소             0
# 지번코드              0
# 대지구분명             0
# 대지구분코드            0
# 법정동명              0
# 법정동코드             0
# 행정동코드             0
# 시군구명              0
# 시군구코드             0
# 시도명               0
# 시도코드              0
# 상권업종소분류명          0
# 상권업종소분류코드         0
# 상권업종중분류명          0
# 상권업종중분류코드         0
# 상권업종대분류명          0
# 상권업종대분류코드         0
# 위도                0
# dtype: int64

# %%
df.isna().sum().sort_values(ascending=False)[:12].index
# Out:
# Index(['호정보', '동정보', '건물부번지', '지점명', '건물명', '층정보', '지번부번지', '표준산업분류코드',
#        '표준산업분류명', '신우편번호', '행정동명', '상호명'],
#       dtype='object')

# %%
not_columns = df.isna().sum().sort_values(ascending=False)[:12].index
df.drop(not_columns, axis = 1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147799 entries, 0 to 147798
# Data columns (total 27 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     147799 non-null  int64
#  1   상권업종대분류코드  147799 non-null  object
#  2   상권업종대분류명   147799 non-null  object
#  3   상권업종중분류코드  147799 non-null  object
#  4   상권업종중분류명   147799 non-null  object
#  5   상권업종소분류코드  147799 non-null  object
#  6   상권업종소분류명   147799 non-null  object
#  7   시도코드       147799 non-null  int64
#  8   시도명        147799 non-null  object
#  9   시군구코드      147799 non-null  int64
#  10  시군구명       147799 non-null  object
#  11  행정동코드      147799 non-null  int64
#  12  법정동코드      147799 non-null  int64
#  13  법정동명       147799 non-null  object
#  14  지번코드       147799 non-null  int64
#  15  대지구분코드     147799 non-null  int64
#  16  대지구분명      147799 non-null  object
#  17  지번본번지      147799 non-null  int64
#  18  지번주소       147799 non-null  object
# ...

# %% [markdown]
# 데이터에서 결측값이 없는 컬럼 값으로 필요한 열을 선택해서 가져오기

# %%
columns = ['상호명',
           '상권업종대분류명' ,
           '상권업종중분류명',
           '상권업종소분류명'  ,
           '시군구명',
           '시도명' ,
           '행정동명', '법정동명', '도로명주소', '경도' , '위도']
df_busan = df[columns].copy()
df_busan.head()
# Out:
#      상호명 상권업종대분류명   상권업종중분류명   상권업종소분류명  시군구명    시도명  행정동명   법정동명  \
# 0    미광장       숙박  모텔/여관/여인숙  모텔/여관/여인숙    중구  부산광역시   부평동  부평동4가
# 1  BHC치킨       음식     닭/오리요리  후라이드/양념치킨   동래구  부산광역시   복산동    복천동
# 2    스텔라       소매       의복의류       일반의류   수영구  부산광역시  남천2동    남천동
# 3   도란도란       음식         한식  한식/백반/한정식  부산진구  부산광역시  개금1동    개금동
# 4  럭키사진관    생활서비스         사진        사진관   사하구  부산광역시   당리동    당리동
#
#                        도로명주소          경도         위도
# 0        부산광역시 중구 보수대로44번길 5  129.023668  35.100979
# 1      부산광역시 동래구 동래로147번길 18  129.087156  35.205267
# 2        부산광역시 수영구 광안해변로 100  129.115397  35.143770
# 3  부산광역시 부산진구 가야대로482번길 29-3  129.024938  35.151645
# 4         부산광역시 사하구 낙동대로 395  128.974794  35.102905

# %%
df_busan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147799 entries, 0 to 147798
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상호명       147798 non-null  object
#  1   상권업종대분류명  147799 non-null  object
#  2   상권업종중분류명  147799 non-null  object
#  3   상권업종소분류명  147799 non-null  object
#  4   시군구명      147799 non-null  object
#  5   시도명       147799 non-null  object
#  6   행정동명      147793 non-null  object
#  7   법정동명      147799 non-null  object
#  8   도로명주소     147799 non-null  object
#  9   경도        147799 non-null  float64
#  10  위도        147799 non-null  float64
# dtypes: float64(2), object(9)
# memory usage: 12.4+ MB

# %%
df_busan.dropna(subset=['상호명'],inplace =True)

# %%
df_busan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147798 entries, 0 to 147798
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상호명       147798 non-null  object
#  1   상권업종대분류명  147798 non-null  object
#  2   상권업종중분류명  147798 non-null  object
#  3   상권업종소분류명  147798 non-null  object
#  4   시군구명      147798 non-null  object
#  5   시도명       147798 non-null  object
#  6   행정동명      147792 non-null  object
#  7   법정동명      147798 non-null  object
#  8   도로명주소     147798 non-null  object
#  9   경도        147798 non-null  float64
#  10  위도        147798 non-null  float64
# dtypes: float64(2), object(9)
# memory usage: 13.5+ MB

# %%
df_busan['상호명_소문자'] = df_busan['상호명'].str.lower()
df_busan['상호명_소문자']
# Out:
# 0             미광장
# 1           bhc치킨
# 2             스텔라
# 3            도란도란
# 4           럭키사진관
#            ...
# 147794     창조전기조명
# 147795       w뷰티샵
# 147796    부관서비스물류
# 147797    천일컴퓨터학원
# 147798         gs
# Name: 상호명_소문자, Length: 147798, dtype: object

# %%
df_busan['상호명_소문자'].value_counts().head(30)
# Out:
# cu         665
# gs25       476
# 세븐일레븐      374
# 카페         363
# 학원         274
# 이마트        209
# 나          194
# 이마트24      129
# 컴포즈커피      127
# 공부방        102
# bbq치킨      101
# 스타벅스        95
# 이디야커피       94
# 크린토피아       91
# 하이          88
# 월드크리닝       83
# 미니스톱        75
# 파리바게뜨       74
# 교촌치킨        72
# 처갓집양념치킨     70
# bhc치킨       68
# 하삼동커피       67
# 시스템         67
# 태후사랑        66
# 아리따움        59
# 명칭없음        56
# 더벤티         55
# 컴퓨터수리       54
# 충무김밥        53
# 까           52
# Name: 상호명_소문자, dtype: int64

# %%
df_busan.loc[df_busan['상호명_소문자'].str.contains('이디아|이디야|ediya'),'상호명_소문자'].shape
# Out:
# (121,)

# %%
len(df_busan[df_busan['상호명_소문자'].str.contains('이디아|이디야|ediya')]['상호명_소문자'])
# Out:
# 121

# %%
df_busan.loc[df_busan['상호명_소문자'].str.contains('이디아|이디야|ediya'),'상호명_소문자']
# Out:
# 290            이디야커피
# 779            이디야커피
# 1025           이디야커피
# 2072           이디아커피
# 6014           이디야커피
#              ...
# 131331      제이디아이스포츠
# 131939         제이디아트
# 140631    이디아커피서대신역점
# 143215         이디야커피
# 143857         이디야커피
# Name: 상호명_소문자, Length: 121, dtype: object

# %%
df_busan[df_busan['상호명_소문자'].str.contains('이디아|이디야|ediya')]['상호명_소문자']
# Out:
# 290            이디야커피
# 779            이디야커피
# 1025           이디야커피
# 2072           이디아커피
# 6014           이디야커피
#              ...
# 131331      제이디아이스포츠
# 131939         제이디아트
# 140631    이디아커피서대신역점
# 143215         이디야커피
# 143857         이디야커피
# Name: 상호명_소문자, Length: 121, dtype: object

# %%
df_cafe = df_busan[df_busan['상호명_소문자'].str.contains('스타벅스|startbucks|이디아|이디야|ediya')].copy()
df_cafe
# Out:
#           상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명  시군구명    시도명  행정동명   법정동명  \
# 290     이디야커피       음식   커피점/카페  커피전문점/카페/다방  해운대구  부산광역시  반송1동    반송동
# 779     이디야커피       음식   커피점/카페  커피전문점/카페/다방   사하구  부산광역시  다대1동    다대동
# 1025    이디야커피       음식   커피점/카페  커피전문점/카페/다방    동구  부산광역시  초량3동    초량동
# 2072    이디아커피       음식   커피점/카페  커피전문점/카페/다방    동구  부산광역시  초량3동    초량동
# 2757     스타벅스       음식   커피점/카페  커피전문점/카페/다방    동구  부산광역시  초량3동    초량동
# ...       ...      ...      ...          ...   ...    ...   ...    ...
# 143215  이디야커피       음식   커피점/카페  커피전문점/카페/다방   사상구  부산광역시   엄궁동    엄궁동
# 143857  이디야커피       음식   커피점/카페  커피전문점/카페/다방   강서구  부산광역시  명지1동    명지동
# 145711   스타벅스       음식   커피점/카페  커피전문점/카페/다방  해운대구  부산광역시   좌1동     좌동
# 145898   스타벅스       음식   커피점/카페  커피전문점/카페/다방   영도구  부산광역시   남항동  대교동1가
# 146240   스타벅스       음식   커피점/카페  커피전문점/카페/다방    남구  부산광역시  대연5동    대연동
#
#                            도로명주소          경도         위도 상호명_소문자
# ...

# %%
df_cafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 290 to 146240
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상호명       240 non-null    object
#  1   상권업종대분류명  240 non-null    object
#  2   상권업종중분류명  240 non-null    object
#  3   상권업종소분류명  240 non-null    object
#  4   시군구명      240 non-null    object
#  5   시도명       240 non-null    object
#  6   행정동명      240 non-null    object
#  7   법정동명      240 non-null    object
#  8   도로명주소     240 non-null    object
#  9   경도        240 non-null    float64
#  10  위도        240 non-null    float64
#  11  상호명_소문자   240 non-null    object
# dtypes: float64(2), object(10)
# memory usage: 24.4+ KB

# %%
df_cafe['브랜드명'] = ''

# %%
df_cafe.loc[df_cafe['상호명_소문자'].str.contains('스타벅스|startbucks'),'브랜드명'] =  '스타벅스'
df_cafe['브랜드명']
# Out:
# 290
# 779
# 1025
# 2072
# 2757      스타벅스
#           ...
# 143215
# 143857
# 145711    스타벅스
# 145898    스타벅스
# 146240    스타벅스
# Name: 브랜드명, Length: 240, dtype: object

# %%
df_cafe.loc[~df_cafe['상호명_소문자'].str.contains('스타벅스|startbucks'),'브랜드명'] =  '이디야'

# %%
df_cafe['브랜드명']
# Out:
# 290        이디야
# 779        이디야
# 1025       이디야
# 2072       이디야
# 2757      스타벅스
#           ...
# 143215     이디야
# 143857     이디야
# 145711    스타벅스
# 145898    스타벅스
# 146240    스타벅스
# Name: 브랜드명, Length: 240, dtype: object

# %%
df_cafe.to_csv('부산시_이디야_스타벅스.csv' , index = False)

# %%
df_cafe = pd.read_csv('부산시_이디야_스타벅스.csv')

# %%
df_cafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상호명       230 non-null    object
#  1   상권업종대분류명  230 non-null    object
#  2   상권업종중분류명  230 non-null    object
#  3   상권업종소분류명  230 non-null    object
#  4   시군구명      230 non-null    object
#  5   시도명       230 non-null    object
#  6   행정동명      230 non-null    object
#  7   법정동명      230 non-null    object
#  8   도로명주소     230 non-null    object
#  9   경도        230 non-null    float64
#  10  위도        230 non-null    float64
#  11  상호명_소문자   230 non-null    object
#  12  브랜드명      230 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 23.5+ KB

# %%
df_cafe.describe(include='O')
# Out:
#          상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명  시군구명    시도명  행정동명 법정동명  \
# count    230      230      230          230   230    230   230  230
# unique    40        1        1            1    16      1   111   82
# top     스타벅스       음식   커피점/카페  커피전문점/카페/다방  해운대구  부산광역시  부전2동   우동
# freq      94      230      230          230    42    230     9   17
#
#                         도로명주소 상호명_소문자  브랜드명
# count                     230     230   230
# unique                    225      40     2
# top     부산광역시 사하구 하신번영로 381-6    스타벅스  스타벅스
# freq                        2      94   118

# %%
df_cafe['상권업종대분류명'].unique()
# Out:
# array(['음식', '소매', '학문/교육', '스포츠'], dtype=object)

# %%
df_cafe['상권업종중분류명'].unique()
# Out:
# array(['커피점/카페', '가방/신발/액세서리', '학원-어학', '기타음식업', '학원-보습교습입시', '패스트푸드',
#        '한식', '실내운동시설', '학원-음악미술무용'], dtype=object)

# %%
df_cafe['상권업종중분류명'].value_counts().plot.barh()
# Out:
# <Axes: >

# %%
df_cafe = df_cafe[df_cafe['상권업종중분류명'] == '커피점/카페'].copy()
df_cafe
# Out:
#           상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명  시군구명    시도명  행정동명   법정동명  \
# 290     이디야커피       음식   커피점/카페  커피전문점/카페/다방  해운대구  부산광역시  반송1동    반송동
# 779     이디야커피       음식   커피점/카페  커피전문점/카페/다방   사하구  부산광역시  다대1동    다대동
# 1025    이디야커피       음식   커피점/카페  커피전문점/카페/다방    동구  부산광역시  초량3동    초량동
# 2072    이디아커피       음식   커피점/카페  커피전문점/카페/다방    동구  부산광역시  초량3동    초량동
# 2757     스타벅스       음식   커피점/카페  커피전문점/카페/다방    동구  부산광역시  초량3동    초량동
# ...       ...      ...      ...          ...   ...    ...   ...    ...
# 143215  이디야커피       음식   커피점/카페  커피전문점/카페/다방   사상구  부산광역시   엄궁동    엄궁동
# 143857  이디야커피       음식   커피점/카페  커피전문점/카페/다방   강서구  부산광역시  명지1동    명지동
# 145711   스타벅스       음식   커피점/카페  커피전문점/카페/다방  해운대구  부산광역시   좌1동     좌동
# 145898   스타벅스       음식   커피점/카페  커피전문점/카페/다방   영도구  부산광역시   남항동  대교동1가
# 146240   스타벅스       음식   커피점/카페  커피전문점/카페/다방    남구  부산광역시  대연5동    대연동
#
#                            도로명주소          경도         위도 상호명_소문자  브랜드명
# ...

# %%
df_cafe['브랜드명'].value_counts()
# Out:
# 스타벅스    118
# 이디야     112
# Name: 브랜드명, dtype: int64

# %%
plt.figure(figsize=[10,5])
sns.countplot(x='시군구명',data =df_cafe,hue='브랜드명')
# Out:
# <Axes: xlabel='시군구명', ylabel='count'>

# %%
sns.countplot(x='브랜드명',data =df_cafe,hue='시군구명')
# Out:
# <Axes: xlabel='브랜드명', ylabel='count'>

# %%
df_cafe.plot.scatter(x= '경도', y ='위도')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>

# %%
sns.scatterplot(x ='경도' ,y='위도', data=df_cafe,hue='브랜드명')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>

# %%
# !pip install folium

# %% [markdown]
# # 파이썬에서 지도를 활용하는 라이브러리

# %%
import folium

# %%
lat = df_cafe['위도'].mean()
long = df_cafe['경도'].mean()
lat,long
# Out:
# (35.163583644408, 129.07229691483366)

# %%
m = folium.Map([lat,long], zoom_start = 11)

for i in df_cafe.index:
  sub_lat = df_cafe.loc[i,"위도"]
  sub_long = df_cafe.loc[i,"경도"]
  title = f'{df_cafe.loc[i,"상호명"]} - {df_cafe.loc[i,"도로명주소"]}'
  color = 'green'
  if df_cafe.loc[i,'브랜드명'] == '이디야':
      color = 'blue'
  folium.CircleMarker([sub_lat,sub_long],
                      radius = 3,
                      color = color ,
                      tooltip= title).add_to(m)

# %%
geo_path = 'busan.json'
import json
geo_json = json.load(open(geo_path, encoding='utf-8'))

# %%
df_cafe_vs = df_cafe.groupby(["시군구명",'브랜드명'])['상호명'].count()
df_cafe_vs = df_cafe_vs.reset_index()
df_cafe_vs.columns =['구','브랜드명','매장수']
df_cafe_vs
# Out:
#        구  브랜드명  매장수
# 0    강서구  스타벅스    3
# 1    강서구   이디야    8
# 2    금정구  스타벅스    8
# 3    금정구   이디야    8
# 4    기장군  스타벅스    4
# 5    기장군   이디야    5
# 6     남구  스타벅스    6
# 7     남구   이디야   14
# 8     동구  스타벅스    4
# 9     동구   이디야    4
# 10   동래구  스타벅스    5
# 11   동래구   이디야   13
# 12  부산진구  스타벅스   19
# 13  부산진구   이디야    8
# 14    북구  스타벅스    2
# 15    북구   이디야    6
# 16   사상구  스타벅스    3
# 17   사상구   이디야    4
# 18   사하구  스타벅스    8
# 19   사하구   이디야   10
# 20    서구  스타벅스    2
# 21    서구   이디야    3
# 22   수영구  스타벅스    6
# 23   수영구   이디야    6
# 24   연제구  스타벅스    6
# 25   연제구   이디야    8
# 26   영도구  스타벅스    1
# 27   영도구   이디야    2
# 28    중구  스타벅스    8
# 29    중구   이디야    4
# 30  해운대구  스타벅스   33
# 31  해운대구   이디야    9

# %%
df_star = df_cafe_vs[df_cafe_vs['브랜드명'] == '스타벅스'].copy()
df_star
# Out:
#        구  브랜드명  매장수
# 0    강서구  스타벅스    3
# 2    금정구  스타벅스    8
# 4    기장군  스타벅스    4
# 6     남구  스타벅스    6
# 8     동구  스타벅스    4
# 10   동래구  스타벅스    5
# 12  부산진구  스타벅스   19
# 14    북구  스타벅스    2
# 16   사상구  스타벅스    3
# 18   사하구  스타벅스    8
# 20    서구  스타벅스    2
# 22   수영구  스타벅스    6
# 24   연제구  스타벅스    6
# 26   영도구  스타벅스    1
# 28    중구  스타벅스    8
# 30  해운대구  스타벅스   33

# %%
m = folium.Map([lat,long], zoom_start = 11)

folium.Choropleth(
    geo_data = geo_json,
    name='chorpleth',
    data=df_star,
    columns =['구','매장수'],
    key_on = 'feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='스타벅스 매장수'
).add_to(m)

# %%
df_star.to_csv("스타벅스.csv" , index = False)

# %%
df_star = pd.read_csv('스타벅스.csv')

# %%
df_star
# Out:
#     Unnamed: 0     구  브랜드명  매장수
# 0            0   강서구  스타벅스    3
# 1            2   금정구  스타벅스    8
# 2            4   기장군  스타벅스    4
# 3            6    남구  스타벅스    6
# 4            8    동구  스타벅스    4
# 5           10   동래구  스타벅스    5
# 6           12  부산진구  스타벅스   19
# 7           14    북구  스타벅스    2
# 8           16   사상구  스타벅스    3
# 9           18   사하구  스타벅스    8
# 10          20    서구  스타벅스    2
# 11          22   수영구  스타벅스    6
# 12          24   연제구  스타벅스    6
# 13          26   영도구  스타벅스    1
# 14          28    중구  스타벅스    8
# 15          30  해운대구  스타벅스   33

# %%
lat = 35.163583644408
long = 129.07229691483366
m = folium.Map([lat,long], zoom_start = 11)

folium.Choropleth(
    geo_data = geo_json,
    name='chorpleth',
    data=df_star,
    columns =['구','매장수'],
    key_on = 'feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='스타벅스 매장수'
).add_to(m)
