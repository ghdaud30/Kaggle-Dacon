# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
# !pip install koreanize_matplotlib

# %%
df = pd.read_csv("/content/20231020155442.csv" )
df.head()
# Out:
#         시점 항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)
# 0  2005.01  아시아나항공       도착    6613   791439   28012
# 1  2005.01  아시아나항공       출발    6610   799835   29576
# 2  2005.01    대한항공       도착    8869  1372897   70544
# 3  2005.01    대한항공       출발    8870  1405847   78329
# 4  2005.01     외항사       도착    3145   443386   28311

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        3696 non-null   float64
#  1   항공사별(1)   3696 non-null   object
#  2   도착출발별(1)  3696 non-null   object
#  3   운항 (편)    3696 non-null   int64
#  4   여객 (명)    3696 non-null   int64
#  5   화물 (톤)    3696 non-null   int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 173.4+ KB

# %%
df['시점'] = df['시점'].astype("object")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        3696 non-null   object
#  1   항공사별(1)   3696 non-null   object
#  2   도착출발별(1)  3696 non-null   object
#  3   운항 (편)    3696 non-null   int64
#  4   여객 (명)    3696 non-null   int64
#  5   화물 (톤)    3696 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 173.4+ KB

# %%
df.isnull().sum()
# Out:
# 시점          0
# 항공사별(1)     0
# 도착출발별(1)    0
# 운항 (편)      0
# 여객 (명)      0
# 화물 (톤)      0
# dtype: int64

# %%
df.nunique()
# Out:
# 시점           224
# 항공사별(1)       13
# 도착출발별(1)       2
# 운항 (편)      2500
# 여객 (명)      3268
# 화물 (톤)      2990
# dtype: int64

# %%
df['시점']
# Out:
# 0       2005.01
# 1       2005.01
# 2       2005.01
# 3       2005.01
# 4       2005.01
#          ...
# 3691    2023.08
# 3692    2023.08
# 3693    2023.08
# 3694    2023.08
# 3695    2023.08
# Name: 시점, Length: 3696, dtype: object

# %%
df['시점'].values
# Out:
# array([2005.01, 2005.01, 2005.01, ..., 2023.08, 2023.08, 2023.08],
#       dtype=object)

# %%
df['연도'] = df['시점'].apply(lambda x : str(x).split('.')[0])
df['연도']
# Out:
# 0       2005
# 1       2005
# 2       2005
# 3       2005
# 4       2005
#         ...
# 3691    2023
# 3692    2023
# 3693    2023
# 3694    2023
# 3695    2023
# Name: 연도, Length: 3696, dtype: object

# %%
df.head()
# Out:
#         시점 항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)    연도
# 0  2005.01  아시아나항공       도착    6613   791439   28012  2005
# 1  2005.01  아시아나항공       출발    6610   799835   29576  2005
# 2  2005.01    대한항공       도착    8869  1372897   70544  2005
# 3  2005.01    대한항공       출발    8870  1405847   78329  2005
# 4  2005.01     외항사       도착    3145   443386   28311  2005

# %%
df.groupby(['연도','항공사별(1)']).sum()['여객 (명)']
# Out:
# <ipython-input-81-3409568a6d32>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['연도','항공사별(1)']).sum()['여객 (명)']
# 연도    항공사별(1)
# 2005  대한항공       34721098
#       아시아나항공     18535331
#       외항사        11319209
# 2006  대한항공       34990013
#       아시아나항공     19284957
#                    ...
# 2023  이스타항공       1607450
#       제주항공       11451691
#       진에어         9821149
#       티웨이항공       9793088
#       플라이강원        256654
# Name: 여객 (명), Length: 164, dtype: int64

# %%
34721098 // 24
# Out:
# 1446712

# %%
df.groupby(['연도','항공사별(1)']).count()['여객 (명)']
# Out:
# 연도    항공사별(1)
# 2005  대한항공       24
#       아시아나항공     24
#       외항사        24
# 2006  대한항공       24
#       아시아나항공     24
#                  ..
# 2023  이스타항공      12
#       제주항공       16
#       진에어        16
#       티웨이항공      16
#       플라이강원      10
# Name: 여객 (명), Length: 164, dtype: int64

# %%
df['연도'] = df['연도'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        3696 non-null   object
#  1   항공사별(1)   3696 non-null   object
#  2   도착출발별(1)  3696 non-null   object
#  3   운항 (편)    3696 non-null   int64
#  4   여객 (명)    3696 non-null   int64
#  5   화물 (톤)    3696 non-null   int64
#  6   연도        3696 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 202.2+ KB

# %%
df.groupby(['항공사별(1)', '연도']).mean()['여객 (명)']
# Out:
# <ipython-input-84-083f6d51fb56>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['항공사별(1)', '연도']).mean()['여객 (명)']
# 항공사별(1)  연도
# 대한항공     2005    1.446712e+06
#          2006    1.457917e+06
#          2007    1.443944e+06
#          2008    1.379018e+06
#          2009    1.266577e+06
#                      ...
# 플라이강원    2019    1.131050e+04
#          2020    1.254183e+04
#          2021    1.140450e+04
#          2022    2.977738e+04
#          2023    2.566540e+04
# Name: 여객 (명), Length: 164, dtype: float64

# %%
df.head()
# Out:
#         시점 항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)
# 0  2005.01  아시아나항공       도착    6613   791439   28012
# 1  2005.01  아시아나항공       출발    6610   799835   29576
# 2  2005.01    대한항공       도착    8869  1372897   70544
# 3  2005.01    대한항공       출발    8870  1405847   78329
# 4  2005.01     외항사       도착    3145   443386   28311

# %%
df_passengers = df.groupby('항공사별(1)')['여객 (명)'].mean()
df_passengers
# Out:
# 항공사별(1)
# 대한항공       1.242783e+06
# 아시아나항공     8.323825e+05
# 에어로케이항공    2.546024e+04
# 에어부산       3.306300e+05
# 에어서울       9.265270e+04
# 에어인천       0.000000e+00
# 에어프레미아     1.422212e+04
# 외항사        6.813250e+05
# 이스타항공      2.298552e+05
# 제주항공       3.954043e+05
# 진에어        3.403002e+05
# 티웨이항공      3.220146e+05
# 플라이강원      1.850308e+04
# Name: 여객 (명), dtype: float64

# %%
df_passengers.plot(kind='bar')
# Out:
# <Axes: xlabel='항공사별(1)'>

# %%
# 연간 평균 여객 수
df.groupby(['항공사별(1)','시점'])['여객 (명)'].mean()
# Out:
# 항공사별(1)  시점
# 대한항공     2005.01    1389372.0
#          2005.02    1283124.5
#          2005.03    1299407.5
#          2005.04    1532864.0
#          2005.05    1545822.5
#                       ...
# 플라이강원    2023.01      29692.5
#          2023.02      33487.0
#          2023.03      29955.5
#          2023.04      24539.0
#          2023.05      10653.0
# Name: 여객 (명), Length: 1848, dtype: float64

# %%
# 항공사별 연간 운항 증가율 계산
a = df.groupby('항공사별(1)')['운항 (편)']
a

# %%
b = a.pct_change() * 100.
b.plot()
# Out:
# <Axes: >

# %%
for key , v in a:
  print(key)
  print(v)
# Out:
# 대한항공
# 2       8869
# 3       8870
# 8       8156
# 9       8150
# 14      8787
#         ...
# 3637    6746
# 3660    7062
# 3661    7064
# 3684    7098
# 3685    7091
# Name: 운항 (편), Length: 448, dtype: int64
# 아시아나항공
# 0       6613
# 1       6610
# 6       6015
# 7       6016
# 12      6489
#         ...
# 3625    4665
# 3648    4831
# 3649    4832
# 3672    4931
# 3673    4931
# Name: 운항 (편), Length: 448, dtype: int64
# 에어로케이항공
# 2978      2
# 2979      2
# 3000     28
# 3001     28
# 3022     96
#        ...
# 3643    180
# 3666    238
# 3667    238
# 3690    352
# 3691    352
# Name: 운항 (편), Length: 62, dtype: int64
# 에어부산
# 334       86
# 335       86
# 346      540
# 347      540
# 358      868
#         ...
# 3627    2723
# 3650    2650
# 3651    2652
# 3674    2628
# 3675    2625
# Name: 운항 (편), Length: 358, dtype: int64
# 에어서울
# 1854    167
# 1855    167
# 1874    248
# 1875    248
# 1894    223
#        ...
# 3631    740
# 3654    614
# 3655    614
# 3678    626
# ...

# %%
df.head()
# Out:
#         시점 항공사별(1) 도착출발별(1)  운항 (편)   여객 (명)  화물 (톤)    연도
# 0  2005.01  아시아나항공       도착    6613   791439   28012  2005
# 1  2005.01  아시아나항공       출발    6610   799835   29576  2005
# 2  2005.01    대한항공       도착    8869  1372897   70544  2005
# 3  2005.01    대한항공       출발    8870  1405847   78329  2005
# 4  2005.01     외항사       도착    3145   443386   28311  2005

# %%
df[df['도착출발별(1)'] == '출발'].groupby('시점')[['운항 (편)','여객 (명)']].sum()
# Out:
#          운항 (편)   여객 (명)
# 시점
# 2005.01   18633  2670910
# 2005.02   17111  2422116
# 2005.03   18356  2463440
# 2005.04   18732  2829839
# 2005.05   19522  2878604
# ...         ...      ...
# 2023.04   31241  5224918
# 2023.05   33424  5543240
# 2023.06   33044  5628668
# 2023.07   34683  5900666
# 2023.08   35166  6030749
#
# [224 rows x 2 columns]

# %%
# 도착 / 출발에 따른 시점 별 연간 운행 및 여객 합산
df[df['도착출발별(1)'] == '도착'].groupby('시점')[['운항 (편)','여객 (명)']].sum()
# Out:
#          운항 (편)   여객 (명)
# 시점
# 2005.01   18627  2607722
# 2005.02   17112  2451062
# 2005.03   18342  2462065
# 2005.04   18735  2823164
# 2005.05   19511  2836185
# ...         ...      ...
# 2023.04   31189  5233125
# 2023.05   33421  5529102
# 2023.06   33028  5618913
# 2023.07   34656  5743000
# 2023.08   35177  6192002
#
# [224 rows x 2 columns]

# %%
space = pd.read_csv('/content/space_missions.csv' ,index_col = "Date" , parse_dates = ["Date"])
space
# Out:
#            Company Name    Location    Cost   Status
# Date
# 2019-02-05  Arianespace      France  200.00  Success
# 2019-02-22       SpaceX         USA   50.00  Success
# 2019-03-02       SpaceX         USA   50.00  Success
# 2019-03-09         CASC       China   29.15  Success
# 2019-03-22  Arianespace      France   37.00  Success
# ...                 ...         ...     ...      ...
# 2020-07-25         CASC       China   64.68  Success
# 2020-07-30          ULA         USA  145.00  Success
# 2020-07-30    Roscosmos  Kazakhstan   65.00  Success
# 2020-08-06         CASC       China   29.75  Success
# 2020-08-07       SpaceX         USA   50.00  Success
#
# [120 rows x 4 columns]

# %%
space.Cost.plot(color = 'green')
# Out:
# <Axes: xlabel='Date'>

# %%
space.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120 entries, 2019-02-05 to 2020-08-07
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  120 non-null    object
#  1   Location      120 non-null    object
#  2   Cost          120 non-null    float64
#  3   Status        120 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 4.7+ KB

# %%
space.plot()
# Out:
# <Axes: xlabel='Date'>
